# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
import ast
# Load the dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#cleaning the data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = (df['job_skills']
                    .apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else [])
                    )

#Filtering the DataFrame for Data Analyst jobs
df_DA = df[df['job_title_short']=='Data Analyst'].copy()

# %%
df_DA_exploded = df_DA.explode('job_skills')
df_DA_exploded
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
df_DA_exploded['month_no']= df_DA_exploded['job_posted_date'].dt.month
df_DA_pivot = df_DA_exploded.pivot_table(index='month_no', columns='job_skills', aggfunc='size', fill_value=0)
df_DA_pivot.loc['Total']=df_DA_pivot.sum()


df_DA_pivot
# Out:
# job_skills  airflow  airtable  alteryx  angular  angular.js  ansible  apl  \
# month_no
# 1               197        17      551       63           2       20    2
# 2               169         2      448       49           0       14    1
# 3               181         4      442       34           0       23    6
# 4               155         4      413       22           0       11    8
# 5               128         8      310       30           0       19    9
# 6               164        14      393       29           0       14    9
# 7               207         4      366       15           0        8    5
# 8               197         3      413       21           0       12   10
# 9               118         4      317       21           0       14    3
# 10              173        11      350       40           0       19    0
# 11              169         7      293       24           0       19    0
# ...

# %%
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_pivot = df_DA_pivot.drop('Total')
df_DA_pivot
# Out:
# job_skills    sql  excel  python  tableau  power bi     r   sas  powerpoint  \
# month_no
# 1           11336   8170    6606     5596      4285  3607  3830        1880
# 2            7947   5772    4751     3936      3307  2576  2634        1291
# 3            7868   5675    4741     4051      3176  2650  2554        1266
# 4            7553   5496    4557     3776      3106  2399  2598        1190
# 5            6617   4773    4070     3245      2695  2093  1940         979
# 6            7584   5724    4707     3812      3275  2442  2174        1173
# 7            7687   5513    4831     3928      3350  2444  2118        1096
# 8            8823   6482    5576     4533      3859  2975  2560        1332
# 9            6829   4886    4229     3446      3118  2146  1880         944
# 10           7474   5217    4693     3709      3340  2380  2114         955
# 11           6652   4776    4233     3284      3012  2159  1738         894
# ...

# %%
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['month'] = df_DA_pivot['month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_pivot = df_DA_pivot.set_index('month')
df_DA_pivot = df_DA_pivot.drop(columns='month_no')

# %% [markdown]
# #### Customizing our Data Analyst Top skills Line chart

# %%
df_DA_pivot.iloc[:, :5].plot(
    kind='line',
    linewidth = 3,
    linestyle = '-',
    colormap= 'cividis',
    marker = 'o',
    figsize = (8,5)
                             )
plt.title('Top 5 Skills for Data Analyst')
plt.xlabel('')
plt.ylabel('Count of Job Postings')
plt.legend(title='')
plt.show()

# %% [markdown]
# #### Customizing our salary vs Demand Scatter plot
# customization has been added in the file Advanced\15_Matplotlib_scatter_plots.ipynb
